# %% [markdown]
# # 📘 Company CSR Question-Answer Retriever – V2
#
# ## 🔍 Objective
#
# This notebook implements a Retrieval-Augmented Generation (RAG) pipeline for extracting information from Corporate Social Responsibility (CSR) reports. Users can ask natural language questions and receive grounded, context-aware answers based on the content of the uploaded PDF.
#
# ---
#
# ## 🧠 Pipeline Overview
#
# The notebook follows a modular RAG architecture built using LangChain and OpenAI, structured as follows:
#
# ---
#
# ### 1. 📄 Document Loading
#
# CSR reports in PDF format are parsed using multiple tools to handle structured and unstructured content:
#
# - `pdfplumber` and `fitz` for text extraction.
# - `pytesseract` and `PIL` for OCR of scanned images.
# - `camelot` for extracting tabular data.
#
# ---
#
# ### 2. ✂️ Text Chunking
#
# The extracted document is split into manageable text chunks using:
#
# ```python
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# ```
#
# - Chunk size: 1000 characters
# - Overlap: 200 characters
#
# This ensures important context is preserved across chunks for better retrieval relevance.
#
# ---
#
# ### 3. 🧠 Embedding and Vector Storage
#
# The chunked text is embedded and stored for semantic search using:
#
# ```python
# from langchain_openai import OpenAIEmbeddings
# from langchain_community.vectorstores import Chroma
# ```
#
# - Each text chunk is embedded using OpenAI’s embedding model.
# - The resulting vectors are stored in a Chroma vector store to enable efficient similarity-based retrieval.
#
# ---
#
# ### 4. 🔎 Query + Retrieval
#
# When a user submits a question, the system performs semantic search to retrieve the most relevant chunks from the stored embeddings:
#
# ```python
# docs = vectorstore.similarity_search(query)
# ```
#
# These retrieved documents provide the contextual foundation for answer generation.
#
# ---
#
# ### 5. 🧾 Prompt Creation
#
# A structured prompt is constructed by combining the retrieved context and the user’s question:
#
# ```python
# from langchain.prompts import ChatPromptTemplate
# ```
#
# Prompt format:
#
# ```
# Use the following context to answer the question. Don’t guess.
#
# {context}
#
# Question: {question}
# ```
#
# This ensures that the model generates responses grounded only in the available information.
#
# ---
#
# ### 6. 🤖 Response Generation
#
# The prompt is passed to a language model to generate the final response:
#
# ```python
# from langchain_openai import ChatOpenAI
# ```
#
# The model uses the structured context and query to return a relevant and accurate answer.
#
# ---
#
# ## ✅ Summary
#
# This notebook demonstrates a modular Retrieval-Augmented Generation (RAG) pipeline for answering natural language questions over CSR PDFs. It uses:
#
# - Multi-tool PDF parsing
# - Overlapping text chunking
# - OpenAI-powered embeddings
# - Chroma-based semantic search
# - Prompt-based interaction with a chat model
#
# This setup is suitable for tasks such as ESG reporting, compliance auditing, and document intelligence across long, unstructured enterprise PDFs.

# %%
import numpy as np
import pandas as pd
import os
from dotenv import load_dotenv
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.load import loads,dumps
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough
from langchain_unstructured import UnstructuredLoader
from langchain.docstore.document import Document
import fitz
import pytesseract
from PIL import Image
import io
import camelot
import pdfplumber
import time

# %%
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'

# %%
load_dotenv(override = True)
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY','your-key-if-not-using-env')

# %%
def pdf_extractor(pdf_path, chunk_size=1000, chunk_overlap=200):
    print("Extracting info from",pdf_path) 
    doc = fitz.open(pdf_path)
    documents = []
    try:
        all_tables = camelot.read_pdf(pdf_path, pages='all')
        tables_by_page = {}
        for table in all_tables:
            page_num = table.parsing_report['page']
            if page_num not in tables_by_page:
                tables_by_page[page_num] = []
            tables_by_page[page_num].append(table)
    except:
        tables_by_page = {}
    
    for page_num in range(doc.page_count):
        page = doc[page_num]
        page_text = ""
        text = page.get_text()
        if text.strip():
            page_text += text
        current_page_num = page_num + 1
        table_count = 0
        
        if current_page_num in tables_by_page:
            for table in tables_by_page[current_page_num]:
                page_text += f"\n\n--- Table {table_count + 1} ---\n"
                page_text += table.df.to_string(index=False)
                table_count += 1
        else:
            try:
                with pdfplumber.open(pdf_path) as pdf_plumber:
                    if page_num < len(pdf_plumber.pages):
                        plumber_page = pdf_plumber.pages[page_num]
                        tables = plumber_page.extract_tables()
                        for table in tables:
                            if table and len(table) > 0:
                                page_text += f"\n\n--- Table {table_count + 1} ---\n"
                                if len(table) > 1:
                                    df = pd.DataFrame(table[1:], columns=table[0])
                                else:
                                    df = pd.DataFrame(table)
                                page_text += df.to_string(index=False)
                                table_count += 1
            except:
                pass
    
        image_list = page.get_images()
        image_count = 0
        
        for img_index, img in enumerate(image_list):
            try:
                xref = img[0]
                pix = fitz.Pixmap(doc, xref)
                if pix.n - pix.alpha < 4:
                    img_data = pix.tobytes("png")
                    pil_img = Image.open(io.BytesIO(img_data))
                    ocr_text = pytesseract.image_to_string(pil_img)
                    if ocr_text.strip():
                        page_text += f"\n\n[Image {image_count + 1} OCR]:\n{ocr_text}"
                        image_count += 1
                pix = None
            except:
                continue
        
        if page_text.strip():
            document = Document(
                page_content=page_text,
                metadata={
                    "source": pdf_path,
                    "page_number": page_num + 1,
                    "total_pages": doc.page_count,
                    "table_count": table_count,
                    "image_count": image_count,
                    "has_tables": table_count > 0,
                    "has_images": image_count > 0,
                    "content_length": len(page_text)
                }
            )
            documents.append(document)
    
    doc.close()
    
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        separators=[
            "\n\n--- Table",
            "\n\n[Image",
            "\n\n\n",
            "\n\n",
            "\n",
            ". ",
            " ",
            ""
        ]
    )
    
    chunks = text_splitter.split_documents(documents)
    
    for i, chunk in enumerate(chunks):
        chunk.metadata["chunk_id"] = i
        chunk.metadata["chunk_length"] = len(chunk.page_content)
    
    return chunks

# %%
def create_vector_db(db_name,embeddings,documents):
    if os.path.exists(db_name):
        print("Database exists.Proceeding to delete")
        Chroma(persist_directory = db_name, embedding_function = embeddings).delete_collection()
    vector_db = Chroma.from_documents(documents = documents, embedding = embeddings, persist_directory = db_name)
    retriever = vector_db.as_retriever()
    return retriever

# %%
def reciprocal_rank_fusion(results: list[list], k = 60):
    fused_scores = {}
    for list_doc in results:
        for rank,doc in enumerate(list_doc):
            #print("Document\n",doc)
            doc_str = dumps(doc)
            #print("Document\n",doc_str)
            if doc_str not in fused_scores:
                fused_scores[doc_str] = 0
            previous_score = fused_scores[doc_str]
            fused_scores[doc_str] += 1/(rank+k)
            
    ranked_res = [(loads(doc),score) for doc,score in sorted(fused_scores.items(), key = lambda x: x[1], reverse = True)]
    
    return ranked_res

# %%
folder_path = "./Input Dataset/"
file_list = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

print(file_list)
# Out:
# ['D4G_0.pdf', 'D4G_1.pdf']

# %%
db_name = 'vector_db'
embeddings = OpenAIEmbeddings()

# %%
template = """You are a helpful assistant that generates multiple search queries based on a single input query. \n
Generate multiple search queries related to: {question} \n
Output (4 queries):"""

# %%
prompt_fus = ChatPromptTemplate.from_template(template)

# %%
generate_queries = (prompt_fus | ChatOpenAI(temperature = 0) | StrOutputParser() | (lambda x: x.split('\n')))

# %%
template = """Answer the following question based on this context:

{context}

Question: {question}
"""

# %%
prompt = ChatPromptTemplate.from_template(template)

# %%
llm = ChatOpenAI(model = 'gpt-4o-mini', temperature = 0)

# %%
df = pd.read_csv('Output Format.csv')

# %%
queries = df.columns.to_list()[1:-1]

# %%
df.columns
# Out:
# Index(['Report Number ', 'Topic of Report ',
#        'Name of Organisation who has generated the report',
#        'Top 5 key highlights of the report like vision, mission etc.,s (In 200 words)',
#        'Is this a new area that company is rolling out a CSR/ESG activity (Yes/ no)',
#        'What is the stragey & Target of the the initaitive',
#        'What is the spend forecast for the initiative ( numeric column )',
#        'Furtue areas of investments based on the report (if any) in 200 words',
#        'Previous areas that the company has worked in (in 200 words) if any ',
#        'What locations are the initiatives plan (in 200 words)',
#        'Max Time taken to run the entire code for each report'],
#       dtype='object')

# %%
report_count = 0
final_df = pd.DataFrame()
for file in file_list:
    start = time.time()
    input_path = folder_path+file
    print(input_path)
    report_count +=1
    qna = {}
    qna['Report Number'] = report_count
    chunks = pdf_extractor(input_path, chunk_size=1200, chunk_overlap=150)
    retriever = create_vector_db(db_name,embeddings,documents = chunks)
    for question in queries:
        question += "?"
        print("Question Asked\n",question)
        retrieval_fusion = generate_queries | retriever.map() | reciprocal_rank_fusion
        final_chain = ({"context" : retrieval_fusion,
                        "question" : itemgetter("question")}
                       | prompt
                       | llm
                       | StrOutputParser()
                      )
        answer = final_chain.invoke({"question":question})
        qna[question] = answer
        print(answer)
    end = time.time()
    qna['Max Time'] = end-start
    data = pd.DataFrame([qna])
    final_df = pd.concat([final_df,data],ignore_index = True)
# Out:
# ./Input Dataset/D4G_0.pdf
# Extracting info from ./Input Dataset/D4G_0.pdf
# Database exists.Proceeding to delete
# Question Asked
#  Topic of Report ?
# The topic of the report is "Corporate Social Responsibility."
# Question Asked
#  Name of Organisation who has generated the report?
# The name of the organization that generated the report is not explicitly mentioned in the provided context. The context only refers to the document as the "2021 CORPORATE SOCIAL RESPONSIBILITY REPORT" without specifying the organization's name.
# Question Asked
#  Top 5 key highlights of the report like vision, mission etc.,s (In 200 words)?
# 1. **Commitment to Sustainability**: Titan emphasizes its dedication to reducing environmental impact through eco-design principles and sustainable practices across its operations, including product design and manufacturing processes.
#
# 2. **Community Engagement**: The company recognizes its role in the communities it operates in, actively participating in local projects and encouraging employee volunteerism to foster positive contributions.
#
# 3. **Governance and Oversight**: The Board of Directors plays a crucial role in overseeing Environmental, Social, and Governance (ESG) commitments, ensuring adherence to social policies related to human rights, health, safety, and diversity.
#
# 4. **Transparency and Reporting**: Titan is committed to transparency in its ESG efforts, launching a dedicated section on its investor relations website for ESG reporting, aligned with the Sustainable Accounting Standards Board (SASB) framework.
#
# 5. **Resilience and Adaptability**: The report highlights Titan's ability to navigate challenges during the COVID-19 pandemic, maintaining operations and supporting employees and communities, showcasing the strength and resilience of its workforce.
#
# These highlights reflect Titan's vision of being a responsible corporate citizen while striving for continuous improvement in sustainability and community engagement.
# Question Asked
#  Is this a new area that company is rolling out a CSR/ESG activity (Yes/ no)?
# No.
# Question Asked
#  What is the stragey & Target of the the initaitive?
# The strategy of the initiative focuses on sustainability and community engagement. Specifically, it involves creating a life cycle assessment process to evaluate new products prior to market launch, ensuring that sustainability criteria are integrated into product development. This includes assessing environmental impacts, such as product weight, fuel consumption, use of recycled materials, and overall product longevity.
#
# The target of the initiative is to reduce the environmental impact of products throughout their life cycle, from inception to production and release. Additionally, the initiative aims to enhance community support through charitable activities and local sponsorships, demonstrating a commitment to making a positive contribution to the communities in which the business operates.
# Question Asked
#  What is the spend forecast for the initiative ( numeric column )?
# The provided context does not contain any specific information regarding a spend forecast for any initiative. It primarily includes excerpts from a document related to sustainability, product development, and corporate social responsibility, but does not specify any numeric values or forecasts related to spending. If you have access to the full document or additional details, please provide that information for a more accurate response.
# Question Asked
#  Furtue areas of investments based on the report (if any) in 200 words?
# The 2021 Corporate Social Responsibility Report from Titan highlights several future areas of investment aimed at enhancing sustainability and operational efficiency. The company emphasizes its commitment to reducing environmental impact through various initiatives. Key areas of focus include:
#
# 1. **Sustainable Practices**: Titan is investing in processes that promote soil compaction and enhance agricultural yield, which indicates a commitment to sustainable farming practices.
#
# 2. **Resource Efficiency**: The report mentions efforts to closely track business operations to identify opportunities for reducing the use of harmful solvents, suggesting a move towards greener alternatives in production processes.
#
# 3. **Recycling and Material Innovation**: There is a focus on finding uses for recycled materials and exploring new design methodologies for facilities that prioritize sustainability.
#
# 4. **Environmental, Social, and Governance (ESG) Reporting**: Titan plans to enhance its ESG reporting, aligning its results with the Sustainable Accounting Standards Board (SASB) guidelines, which indicates a commitment to transparency and accountability in sustainability efforts.
#
# 5. **Continuous Improvement**: The CEO's message underscores a dedication to ongoing improvements in environmental impact, suggesting that future investments will be directed towards innovative technologies and practices that further reduce the company's ecological footprint.
#
# These areas reflect Titan's proactive approach to sustainability and its intention to invest in initiatives that support long-term environmental stewardship.
# Question Asked
#  Previous areas that the company has worked in (in 200 words) if any ?
# Titan has over 130 years of experience in the off-highway wheel manufacturing business, focusing on delivering high-quality products while ensuring a safe and welcoming workplace for employees. The company has a significant impact on various economic sectors that contribute to greenhouse gas emissions, particularly in agriculture, construction, and mining.
#
# In addition to its core manufacturing operations, Titan is actively involved in community support and social responsibility initiatives. The company encourages its employees to engage in charitable activities, such as clothing drives and supporting cancer research organizations. For instance, in 2021, the Latin America team donated 1,300 articles of clothing and shoes to those in need, while Titan Europe supported transportation assistance projects for the elderly and disabled.
#
# Titan also emphasizes diversity and inclusion within its workforce, with efforts to increase gender diversity and highlight women-led business units. The company has maintained operational continuity during the COVID-19 pandemic, ensuring the safety of its employees while providing essential products to support agriculture and construction industries. Overall, Titan's commitment extends beyond manufacturing to encompass community engagement and social responsibility.
# Question Asked
#  What locations are the initiatives plan (in 200 words)?
# The initiatives outlined in the document are planned for various locations across different continents. In North America, the focus is on the tire division, with specific locations mentioned such as Quincy, IL; Bryan, OH; Des Moines, IA; Freeport, IL; Union City, TN; Jefferson, GA; Elkhorn, WI; Holden, WV; and Winston-Salem, NC.
#
# In South America, initiatives are planned in Brazil, specifically in Atibaia, SP; Paraupebas, PA; and São Paulo, SP.
#
# Additionally, the document lists several locations in Europe, including Flers, France; Gevelsburg, Germany; Jesi, Italy; Kidderminster, UK; Monreal del Campo, Spain; Potenza, Italy; St. Helens, UK; Valsamoggia, Italy; and Volgograd, Russia.
#
# In Asia, initiatives are planned in Aydin, Turkey; Heidelberg, South Africa; Jakarta, Indonesia; Luoizhou, China; Tianjin, China; and Visakhapatnam, Andhra Pradesh, India.
#
# In Australia, the locations include Emerald, QLD; Mildura, VIC; Muswellbrook, NSW; Perth, WA; Sydney, NSW; and Yatala, QLD. These initiatives reflect a global footprint aimed at enhancing environmental, social, and governance (ESG) practices across various regions.
# ./Input Dataset/D4G_1.pdf
# Extracting info from ./Input Dataset/D4G_1.pdf
# Database exists.Proceeding to delete
# Question Asked
#  Topic of Report ?
# The topic of the report is "Environmental, Social & Governance" (ESG).
# Question Asked
#  Name of Organisation who has generated the report?
# The organization that generated the report is Broadcom.
# Question Asked
#  Top 5 key highlights of the report like vision, mission etc.,s (In 200 words)?
# The report emphasizes Broadcom's commitment to sustainable development and corporate responsibility through several key highlights:
#
# 1. **Sustainable Development Strategy**: Broadcom outlines its strategy to manage environmental impacts, focusing on climate-related risks and opportunities, aligning with global standards such as TCFD (Task Force on Climate-related Financial Disclosures).
#
# 2. **Environmental Metrics**: The organization discloses metrics for assessing climate-related risks, including Scope 1, Scope 2, and Scope 3 greenhouse gas emissions, along with targets for emissions reduction and resource management.
#
# 3. **Employee Engagement**: Broadcom prioritizes workforce engagement, emphasizing diversity, equity, and inclusion, as well as employee health and safety, which are integral to its corporate governance.
#
# 4. **Stakeholder Engagement**: The report highlights the importance of engaging with stakeholders, including employees, customers, and stockholders, to identify and prioritize ESG issues that significantly impact the business.
#
# 5. **Governance and Ethics**: Broadcom underscores its commitment to ethical practices and corporate governance, ensuring transparency and accountability in its operations and decision-making processes.
#
# These highlights reflect Broadcom's vision of integrating sustainability into its core business strategy while fostering a responsible corporate culture.
# Question Asked
#  Is this a new area that company is rolling out a CSR/ESG activity (Yes/ no)?
# No.
# Question Asked
#  What is the stragey & Target of the the initaitive?
# The strategy of the initiative focuses on disclosing the actual and potential impacts of climate-related risks and opportunities on the organization’s businesses, strategy, and financial planning, particularly where such information is material. It includes assessing the resilience of the organization’s strategy under different climate-related scenarios, such as a 2°C or lower scenario. Although a formal scenario analysis has not been conducted yet, the organization plans to incorporate climate scenario analysis into its existing risk and opportunity assessment processes.
#
# Regarding targets, the organization has set a GHG emissions reduction target and monitors its greenhouse gas emissions, energy use, and water use data. The metrics and targets used to assess and manage relevant climate-related risks and opportunities are disclosed in the Environment section of the report.
# Question Asked
#  What is the spend forecast for the initiative ( numeric column )?
# The provided context does not contain any information regarding a spend forecast for any initiative. It primarily discusses greenhouse gas emissions, climate-related risks, and governance related to environmental, social, and governance (ESG) disclosures. If you have a specific document or section that includes financial forecasts or spending details, please provide that for further assistance.
# Question Asked
#  Furtue areas of investments based on the report (if any) in 200 words?
# The report identifies several future areas of investment focused on climate-related opportunities. Key among these is the development of new products and the enhancement of existing ones through research, development, and innovation. This approach aims to increase revenue by meeting the growing demand for energy-efficient products and accessing new markets.
#
# A significant focus is on optimizing products for various market segments, ensuring they deliver high performance while minimizing power consumption. For instance, the report highlights the BCM4778, a GNSS receiver chip that significantly reduces power usage, thereby extending the battery life of devices like smartwatches. This innovation not only meets consumer demand for longer-lasting devices but also aligns with the global shift towards green energy systems.
#
# Additionally, the report emphasizes the importance of engaging with stakeholders, including employees and customers, to identify and prioritize ESG issues that could impact the business. This stakeholder engagement is crucial for aligning investment strategies with market trends and sustainability goals, ensuring that future investments are both economically viable and environmentally responsible. Overall, the report suggests a strategic commitment to innovation and sustainability as key drivers for future investments.
# Question Asked
#  Previous areas that the company has worked in (in 200 words) if any ?
# The company has focused on several key areas, particularly in relation to sustainable development and corporate responsibility. One significant aspect is the management of its environmental impact, which includes strategies, policies, and practices aimed at reducing the ecological footprint of its operations. The company emphasizes stakeholder engagement and ethical practices, indicating a commitment to transparency and accountability in its reporting.
#
# Additionally, the company has identified climate-related opportunities, particularly in product development and market expansion. This includes innovating new products and enhancing existing ones to meet the growing demand for energy-efficient solutions. For instance, the development of the BCM4778 GNSS receiver chip exemplifies their focus on reducing power consumption, which is crucial for extending the battery life of devices like smartphones and smartwatches.
#
# Moreover, the company is adapting to the shift towards green energy systems, indicating a proactive approach to align its offerings with emerging market trends. Overall, the company’s previous areas of work reflect a strong commitment to sustainability, innovation, and corporate responsibility, positioning it to capitalize on new opportunities in a changing global landscape.
# Question Asked
#  What locations are the initiatives plan (in 200 words)?
# The initiatives mentioned in the context are primarily focused on Bengaluru, Mumbai, and Pune in India.
#
# 1. **One Billion Drops Program**: This initiative, supported by United Way of Bengaluru, aims to enhance groundwater levels in and around Bengaluru by conserving rainwater. The goal is to build 10,000 percolation pits to conserve 1 billion liters of rainwater annually. Additionally, there is a project to provide access to safe drinking water for villages in rural areas surrounding Bengaluru.
#
# 2. **GENDHER Program**: Also supported by United Way of Bengaluru, this program focuses on providing reproductive health and gender sensitivity education in schools, creating safe spaces for young women, and distributing feminine hygiene kits. This initiative is part of broader efforts to promote gender equality and education for young women in the region.
#
# Overall, the initiatives are concentrated in urban areas like Bengaluru, with outreach efforts extending to rural villages nearby, as well as in other major cities like Mumbai and Pune, indicating a commitment to addressing both urban and rural community needs.

# %%
final_df
# Out:
#    Report Number                                  Topic of Report ?  \
# 0              1  The topic of the report is "Corporate Social R...
# 1              2  The topic of the report is "Environmental, Soc...
#
#   Name of Organisation who has generated the report?  \
# 0  The name of the organization that generated th...
# 1  The organization that generated the report is ...
#
#   Top 5 key highlights of the report like vision, mission etc.,s (In 200 words)?  \
# 0  1. **Commitment to Sustainability**: Titan emp...
# 1  The report emphasizes Broadcom's commitment to...
#
#   Is this a new area that company is rolling out a CSR/ESG activity (Yes/ no)?  \
# 0                                                No.
# 1                                                No.
#
#   What is the stragey & Target of the the initaitive?  \
# 0  The strategy of the initiative focuses on sust...
# 1  The strategy of the initiative focuses on disc...
#
#   What is the spend forecast for the initiative ( numeric column )?  \
# 0  The provided context does not contain any spec...
# 1  The provided context does not contain any info...
#
#   Furtue areas of investments based on the report (if any) in 200 words?  \
# 0  The 2021 Corporate Social Responsibility Repor...
# 1  The report identifies several future areas of ...
#
#   Previous areas that the company has worked in (in 200 words) if any ?  \
# 0  Titan has over 130 years of experience in the ...
# 1  The company has focused on several key areas, ...
#
#   What locations are the initiatives plan (in 200 words)?    Max Time
# 0  The initiatives outlined in the document are p...        72.692199
# 1  The initiatives mentioned in the context are p...       114.500301

# %%
final_df.to_csv('Output.csv')
